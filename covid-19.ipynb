# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import matplotlib.pyplot as olt

# %%
data = pd.read_csv('covid19.csv')

# %%
grouped = data.groupby("Date",sort = False)['State/UnionTerritory','ConfirmedIndianNational','ConfirmedForeignNational','Cured','Deaths'].sum().reset_index()
grouped
# Out:
# C:\Users\lenovo\miniconda3\envs\myenviron\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#         Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# 0   30/01/20                        1                         0      0       0
# 1   31/01/20                        1                         0      0       0
# 2   01/02/20                        2                         0      0       0
# 3   02/02/20                        3                         0      0       0
# 4   03/02/20                        3                         0      0       0
# 5   04/02/20                        3                         0      0       0
# 6   05/02/20                        3                         0      0       0
# 7   06/02/20                        3                         0      0       0
# 8   07/02/20                        3                         0      0       0
# 9   08/02/20                        3                         0      0       0
# 10  09/02/20                        3                         0      0       0
# 11  10/02/20                        3                         0      0       0
# 12  11/02/20                        3                         0      0       0
# 13  12/02/20                        3                         0      0       0
# 14  13/02/20                        3                         0      0       0
# 15  14/02/20                        3                         0      0       0
# 16  15/02/20                        3                         0      0       0
# 17  16/02/20                        3                         0      0       0
# 18  17/02/20                        3                         0      0       0
# 19  18/02/20                        3                         0      0       0
# 20  19/02/20                        3                         0      0       0
# 21  20/02/20                        3                         0      0       0
# 22  21/02/20                        3                         0      0       0
# 23  22/02/20                        3                         0      0       0
# 24  23/02/20                        3                         0      0       0
# 25  24/02/20                        3                         0      0       0
# 26  25/02/20                        3                         0      0       0
# 27  26/02/20                        3                         0      0       0
# 28  27/02/20                        3                         0      0       0
# 29  28/02/20                        3                         0      0       0
# 30  29/02/20                        3                         0      0       0
# 31  01/03/20                        3                         0      0       0
# 32  02/03/20                        5                         0      0       0
# 33  03/03/20                        5                         1      3       0
# 34  04/03/20                       12                        16      3       0
# 35  05/03/20                       14                        16      3       0
# 36  06/03/20                       15                        16      3       0
# 37  07/03/20                       18                        16      3       0
# 38  08/03/20                       23                        16      3       0
# 39  09/03/20                       30                        16      3       0
# 40  10/03/20                       42                        16      3       0
# 41  11/03/20                       44                        16      3       0
# 42  12/03/20                       57                        17      3       0
# 43  13/03/20                       64                        17      3       1
# 44  14/03/20                       67                        17     10       2
# 45  15/03/20                       93                        17     13       2
# 46  16/03/20                       97                        17     13       2
# 47  17/03/20                      113                        24     14       3
# 48  18/03/20                      126                        25     14       3
# 49  19/03/20                      148                        25     20       4
# 50  20/03/20                      191                        32     23       4
# 51  21/03/20                      244                        39     23       4

# %%
grouped['sum'] = grouped.iloc[:,1:].sum(axis=1)
grouped
# Out:
#         Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0   30/01/20                        1                         0      0
# 1   31/01/20                        1                         0      0
# 2   01/02/20                        2                         0      0
# 3   02/02/20                        3                         0      0
# 4   03/02/20                        3                         0      0
# 5   04/02/20                        3                         0      0
# 6   05/02/20                        3                         0      0
# 7   06/02/20                        3                         0      0
# 8   07/02/20                        3                         0      0
# 9   08/02/20                        3                         0      0
# 10  09/02/20                        3                         0      0
# 11  10/02/20                        3                         0      0
# 12  11/02/20                        3                         0      0
# 13  12/02/20                        3                         0      0
# 14  13/02/20                        3                         0      0
# 15  14/02/20                        3                         0      0
# 16  15/02/20                        3                         0      0
# 17  16/02/20                        3                         0      0
# 18  17/02/20                        3                         0      0
# 19  18/02/20                        3                         0      0
# 20  19/02/20                        3                         0      0
# 21  20/02/20                        3                         0      0
# 22  21/02/20                        3                         0      0
# 23  22/02/20                        3                         0      0
# 24  23/02/20                        3                         0      0
# 25  24/02/20                        3                         0      0
# 26  25/02/20                        3                         0      0
# 27  26/02/20                        3                         0      0
# 28  27/02/20                        3                         0      0
# 29  28/02/20                        3                         0      0
# 30  29/02/20                        3                         0      0
# 31  01/03/20                        3                         0      0
# 32  02/03/20                        5                         0      0
# 33  03/03/20                        5                         1      3
# 34  04/03/20                       12                        16      3
# 35  05/03/20                       14                        16      3
# 36  06/03/20                       15                        16      3
# 37  07/03/20                       18                        16      3
# 38  08/03/20                       23                        16      3
# 39  09/03/20                       30                        16      3
# 40  10/03/20                       42                        16      3
# 41  11/03/20                       44                        16      3
# 42  12/03/20                       57                        17      3
# 43  13/03/20                       64                        17      3
# 44  14/03/20                       67                        17     10
# 45  15/03/20                       93                        17     13
# 46  16/03/20                       97                        17     13
# 47  17/03/20                      113                        24     14
# 48  18/03/20                      126                        25     14
# 49  19/03/20                      148                        25     20
# 50  20/03/20                      191                        32     23
# 51  21/03/20                      244                        39     23
#
#     Deaths  sum
# 0        0    1
# 1        0    1
# 2        0    2
# 3        0    3
# 4        0    3
# 5        0    3
# 6        0    3
# 7        0    3
# 8        0    3
# 9        0    3
# 10       0    3
# 11       0    3
# 12       0    3
# 13       0    3
# 14       0    3
# 15       0    3
# 16       0    3
# 17       0    3
# 18       0    3
# 19       0    3
# 20       0    3
# 21       0    3
# 22       0    3
# 23       0    3
# 24       0    3
# 25       0    3
# 26       0    3
# 27       0    3
# 28       0    3
# 29       0    3
# 30       0    3
# 31       0    3
# 32       0    5
# 33       0    9
# 34       0   31
# 35       0   33
# 36       0   34
# 37       0   37
# 38       0   42
# 39       0   49
# 40       0   61
# 41       0   63
# 42       0   77
# 43       1   85
# 44       2   96
# 45       2  125
# 46       2  129
# 47       3  154
# 48       3  168
# 49       4  197
# 50       4  250
# 51       4  310

# %%
grouped.plot(kind = 'line',x = 'Date',y='sum')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
specific_dayes = grouped.iloc[34:,:]
specific_dayes
# Out:
#         Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 34  04/03/20                       12                        16      3
# 35  05/03/20                       14                        16      3
# 36  06/03/20                       15                        16      3
# 37  07/03/20                       18                        16      3
# 38  08/03/20                       23                        16      3
# 39  09/03/20                       30                        16      3
# 40  10/03/20                       42                        16      3
# 41  11/03/20                       44                        16      3
# 42  12/03/20                       57                        17      3
# 43  13/03/20                       64                        17      3
# 44  14/03/20                       67                        17     10
# 45  15/03/20                       93                        17     13
# 46  16/03/20                       97                        17     13
# 47  17/03/20                      113                        24     14
# 48  18/03/20                      126                        25     14
# 49  19/03/20                      148                        25     20
# 50  20/03/20                      191                        32     23
# 51  21/03/20                      244                        39     23
#
#     Deaths  sum
# 34       0   31
# 35       0   33
# 36       0   34
# 37       0   37
# 38       0   42
# 39       0   49
# 40       0   61
# 41       0   63
# 42       0   77
# 43       1   85
# 44       2   96
# 45       2  125
# 46       2  129
# 47       3  154
# 48       3  168
# 49       4  197
# 50       4  250
# 51       4  310

# %%
list_ = specific_dayes.values.tolist()
list_
# Out:
# [['04/03/20', 12, 16, 3, 0, 31],
#  ['05/03/20', 14, 16, 3, 0, 33],
#  ['06/03/20', 15, 16, 3, 0, 34],
#  ['07/03/20', 18, 16, 3, 0, 37],
#  ['08/03/20', 23, 16, 3, 0, 42],
#  ['09/03/20', 30, 16, 3, 0, 49],
#  ['10/03/20', 42, 16, 3, 0, 61],
#  ['11/03/20', 44, 16, 3, 0, 63],
#  ['12/03/20', 57, 17, 3, 0, 77],
#  ['13/03/20', 64, 17, 3, 1, 85],
#  ['14/03/20', 67, 17, 10, 2, 96],
#  ['15/03/20', 93, 17, 13, 2, 125],
#  ['16/03/20', 97, 17, 13, 2, 129],
#  ['17/03/20', 113, 24, 14, 3, 154],
#  ['18/03/20', 126, 25, 14, 3, 168],
#  ['19/03/20', 148, 25, 20, 4, 197],
#  ['20/03/20', 191, 32, 23, 4, 250],
#  ['21/03/20', 244, 39, 23, 4, 310]]

# %%
list2 =[]

for i in range(17):
    list2.append( (list_[i+1][5]-list_[i][5])/list_[i+1][5])
   

#list2
r = sum(list2)/len(list2)

# %%
import math

P_o = 31
t = 26
P_t = P_o*(math.exp(r*t))
P_t
# Out:
# 785.4720867023805
